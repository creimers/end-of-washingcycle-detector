# %%
import pandas as pd

# %%
df = pd.read_csv('accelleration.log', header=None, delimiter=" ")
columns = ["acc_x_min", "acc_x_max", "acc_x_mean", "acc_x_std", "acc_y_min", "acc_y_max", "acc_y_mean", "acc_y_std", "acc_z_min", "acc_z_max", "acc_z_mean", "acc_z_std"]
df.columns = columns
df["acc_x_min"] = df["acc_x_min"].map(lambda x: x.split("INFO:root:")[1])
df.head()
# Out:
#   acc_x_min  acc_x_max  acc_x_mean  acc_x_std  acc_y_min  acc_y_max  \
# 0     -5.00       -5.0       -5.00       0.00      -34.0      -34.0
# 1     -5.00       -5.0       -5.00       0.00      -34.0      -34.0
# 2     -5.00       -5.0       -5.00       0.00      -34.0      -34.0
# 3     -5.00       -5.0       -5.00       0.00      -34.0      -34.0
# 4     -5.00       -4.0       -4.25       0.43      -52.0      -34.0
#
#    acc_y_mean  acc_y_std  acc_z_min  acc_z_max  acc_z_mean  acc_z_std
# 0       -34.0       0.00      504.0      504.0       504.0       0.00
# 1       -34.0       0.00      504.0      504.0       504.0       0.00
# 2       -34.0       0.00      504.0      504.0       504.0       0.00
# 3       -34.0       0.00      504.0      504.0       504.0       0.00
# 4       -47.5       7.79      504.0      762.0       697.5     111.72
